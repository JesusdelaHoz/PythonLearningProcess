# %% [markdown]
# # Ejercicios Modulo 5. JSON
#
# Consideraciones a tener en cuenta:
#
# * Guardar este documento con el siguiente formato para su entrega: __M5_03_nombre_apellido1_apellido2__
# * Realizar los ejercicios con las herramientas vistas en las sesiones.
# * Comentar el código
# * Utilizar nombres de variables apropiados, si vais a guardar una nota, llamar a esa variable nota, no n o x

# %% [markdown]
# # JSON (JavaScript Object Notation)

# %% [markdown]
# 1) A continuación se muestra un JSON String
#
# {"jefe_proyecto": {"Nombre": "Juan","Edad": 28,"Experiencia": ["Gestion","Finanzas","Bases de datos"],"Residencia": "Madrid","HorasProyecto": 3500},"empleados": [{"Nombre": "Elena","Edad": 26,"Experiencia": ["JavaScript","Python"],"Residencia": "Madrid","HorasProyecto": 500},{"Nombre": "Luis","Edad": 31,"Experiencia": ["Django","Flask","Pyramid"],"Residencia": "Barcelona","HorasProyecto": 1100}]}
#
# * Si es necesario utiliza un visualizador de JSON para entenderlo.
# * El objetivo es crear un diccionario con todos los datos y estructuras internas necesarias para que sea igual que el JSON String
# * Vete creando estructuras más pequeñas hasta que llegues a formar el mismo JSON string que ves arriba
# * Una vez que lo tengas creado, vamos a operar con él
# * Almacena esta estructura (el diccionario) en una variable
# * Comprueba su tipo y muéstrala por pantalla
# * Crea dos variables: horas_empleados y horas_jefe
# * Extrae las horas del jefe e introducelas en su variable
# * Crea un bucle que recorra el número de empleados que se tienen en la estructura, y para cada empleado vete sumando sus horas en su correspondiente variable
# * Suma todas las horas y muéstralas por pantalla

# %%
diccTrabajadores = {
    "jefe_proyecto":{"Nombre":"Juan", 
                     "Edad": 28, 
                     "Experiencia":["Gestion", "Finanzas", "Bases de datos"], 
                     "Residencia": "Madrid", 
                     "HorasProyecto": 3500}, 
    "empleados":[{"Nombre":"Elena", 
                  "Edad": 26, 
                  "Experiencia":["JavaScript", "Python"], 
                  "Residencia": "Madrid", 
                  "HorasProyecto": 500}, 
                 {"Nombre":"Luis", 
                  "Edad": 31, 
                  "Experiencia":["Django", "Flask", "Pyramid"], 
                  "Residencia": "Barcelona", 
                  "HorasProyecto": 1100}]
 }
print(type(dicc_Json)) # Tiene que ser de tipo 'dict'
horas_empleados = int()
horas_jefe = diccTrabajadores["jefe_proyecto"]["HorasProyecto"]

# Vamos con la iteracion en las horas de los empleados
listaEmpleados = diccTrabajadores["empleados"]
for i in listaEmpleados:
    horas_empleados += i["HorasProyecto"]
    
# Sumamos las horas totales de ambas variables
horas_proyecto = horas_empleados + horas_jefe
print("El tiempo de experiencia del grupo de trabajo es de", horas_proyecto, "horas")
# Out:
# <class 'dict'>
# El tiempo de experiencia del grupo de trabajo es de 5100 horas

# %% [markdown]
# 2) En el ejercicio anterior has trabajado con un diccionario que tu mismo/a creaste, conviértelo a un formato JSON String, muestra su tipo y los datos por pantalla
# ¿Para qué nos sirve este formato?

# %%
import json

json_diccTrabajadores = json.dumps(diccTrabajadores)
print(type(diccTrabajadores))
print(type(json_diccTrabajadores), json_diccTrabajadores)

# Sirve para enviar datos o recibirlos de una manera estructurada, como tipo JSON string, y asi tener una organizacion
# generalizada de como se recibe y envian datos desde distintos lenguajes y sitios (aplicaciones, bases de datos
# entre proyectos, etc..). Generando asi un tipo de fichero 'entendible y legible' gracias a una estructura ya fijada.
# Tambien por que la informacion metida en estos fichero JSON viene muy bien comprimida y no ocupa casi espacio.
# Out:
# <class 'dict'>
# <class 'str'> {"jefe_proyecto": {"Nombre": "Juan", "Edad": 28, "Experiencia": ["Gestion", "Finanzas", "Bases de datos"], "Residencia": "Madrid", "HorasProyecto": 3500}, "empleados": [{"Nombre": "Elena", "Edad": 26, "Experiencia": ["JavaScript", "Python"], "Residencia": "Madrid", "HorasProyecto": 500}, {"Nombre": "Luis", "Edad": 31, "Experiencia": ["Django", "Flask", "Pyramid"], "Residencia": "Barcelona", "HorasProyecto": 1100}]}

# %% [markdown]
# 3) A veces os encontraréis con JSON que tendréis que modificar. Para ello tenéis que decodificarlos, realizar las modificaciones pertinentes y volver a codificarlo para dejarlo como JSON de nuevo. En el siguiente ejemplo os habéis dado cuenta de que hay algunos errores:
# * A Superman le falta como poder "Volar"
# * En Batman, la edad es 35, no 350
# * En Batman, le sobra el poder de "Rayos en los ojos"
# * En Wonder Woman le falta el poder "Lazo de la verdad"
# * Después de corregir todo esto, transforma estos datos en un JSON String

# %%
# NO TOCAR NADA DE ESTE BLOQUE
superheroes = {
	"nombreEquipo": "Super Hero Squad",
	"ciudad": "Metro City",
	"formado": 2016,
	"baseSecreta": "Super Tower",
	"activo": "Si",
	"miembros": [
		{
			"nombre": "SuperMan",
			"edad": 29,
			"identidadSecreta": "Clart Kent",
			"poderes": [
				"Super fuerza",
				"Super velocidad",
				"Rayos en los ojos"
			]
		},
		{
			"nombre": "Batman",
			"edad": 350,
			"identidadSecreta": "Bruce Wayne",
			"poderes": [
				"Detective",
				"Dinero",
				"Rayos en los ojos"
			]
		},
		{
			"nombre": "Wonder Woman",
			"edad": 900,
			"identidadSecreta": "Diana de Temiscira",
			"poderes": [
				"Super fuerza",
				"Super velocidad"
			]
		}
	]
}

# %%
print(type(superheroes)) # Este todavia no esta codificado por lo que trabajaremos ya con el
superheroes["miembros"][0]["poderes"].append("Volar")
superheroes["miembros"][1]["edad"] = 35
del superheroes["miembros"][1]["poderes"][2]
superheroes["miembros"][2]["poderes"].append("Lazo de la verdad")
print(superheroes)

# Codificamos en JSON
jsonSuperheroes = json.dumps(superheroes)
print(type(jsonSuperheroes))
# Out:
# <class 'dict'>
# {'nombreEquipo': 'Super Hero Squad', 'ciudad': 'Metro City', 'formado': 2016, 'baseSecreta': 'Super Tower', 'activo': 'Si', 'miembros': [{'nombre': 'SuperMan', 'edad': 29, 'identidadSecreta': 'Clart Kent', 'poderes': ['Super fuerza', 'Super velocidad', 'Rayos en los ojos', 'Volar']}, {'nombre': 'Batman', 'edad': 35, 'identidadSecreta': 'Bruce Wayne', 'poderes': ['Detective', 'Dinero']}, {'nombre': 'Wonder Woman', 'edad': 900, 'identidadSecreta': 'Diana de Temiscira', 'poderes': ['Super fuerza', 'Super velocidad', 'Lazo de la verdad']}]}
# <class 'str'>

# %% [markdown]
# 4) En base al ejercicio anterior, modifica la estructura de super para lograr que miembros tenga dos ramas: "miembrosActivos" y "miembrosInactivos", donde cada una de estas ramas, almacenen los héroes que están en activo y los que no. En este caso, introduce a SuperMan y Wonder Woman en la lista de activos y a Batman en la de Inactivos. Esta modificación puedes hacerla como quieras, o bien programando las estructuras de datos e ir componiéndolo o bien cogiendo el JSON y modificándolo sobre él mismo. Al finalizar puedes comprobar tu JSON en un visualizador online (http://jsonviewer.stack.hu/)

# %%
# Decodificamos el JSON
superEstrucNueva = json.loads(jsonSuperheroes)

# Añadimos las dos ramas a los miembros, metiendo envez un lista, un diccionario que tenga dos grupos de lista como valor
listaInactivos = [superEstrucNueva["miembros"][1]]
listaActivos = [superEstrucNueva["miembros"][0], superEstrucNueva["miembros"][2]]
superEstrucNueva["miembros"] = {"miembrosActivos": listaActivos, 
                                "miembrosInactivos": listaInactivos}

# Volvemos a codificar y adjuntamos el resultado
json_superEstrucNueva = json.dumps(superEstrucNueva)
print(type(json_superEstrucNueva), "\n", json_superEstrucNueva)
# Out:
# <class 'str'>
#  {"nombreEquipo": "Super Hero Squad", "ciudad": "Metro City", "formado": 2016, "baseSecreta": "Super Tower", "activo": "Si", "miembros": {"miembrosActivos": [{"nombre": "SuperMan", "edad": 29, "identidadSecreta": "Clart Kent", "poderes": ["Super fuerza", "Super velocidad", "Rayos en los ojos", "Volar"]}, {"nombre": "Wonder Woman", "edad": 900, "identidadSecreta": "Diana de Temiscira", "poderes": ["Super fuerza", "Super velocidad", "Lazo de la verdad"]}], "miembrosInactivos": [{"nombre": "Batman", "edad": 35, "identidadSecreta": "Bruce Wayne", "poderes": ["Detective", "Dinero"]}]}}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 5) En el siguiente código, accedemos a un JSON de forma remota, a partir de la respuesta, realizar lo siguiente:
# * Mostrar el tipo de dato que se ha recibido
# * Mostrar los datos recibidos
# * Mostrar el número de personas que se encuentran actualmente en el espacio
# * Realizar un bucle que recorra a todas esas personas y muestre nombre y nave en la que se encuentra.

# %%
import requests

# API que nos comunica cuantas personas se encuentran actualmente en el espacio
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()

print(type(data))
# Recibimos un json ya decodificado

# Podemos acceder a el como un diccionario normal
print(data, "\n")
print("El numero de personas que estan en el espacion es de un total de", data["number"])

for i in data["people"]:
    print("El astronauta {} se encuentra en la nave {}".format(i["name"], i["craft"]))
# Out:
# <class 'dict'>
# {'number': 10, 'people': [{'craft': 'Shenzhou 13', 'name': 'Zhai Zhigang'}, {'craft': 'Shenzhou 13', 'name': 'Wang Yaping'}, {'craft': 'Shenzhou 13', 'name': 'Ye Guangfu'}, {'craft': 'ISS', 'name': 'Raja Chari'}, {'craft': 'ISS', 'name': 'Tom Marshburn'}, {'craft': 'ISS', 'name': 'Kayla Barron'}, {'craft': 'ISS', 'name': 'Matthias Maurer'}, {'craft': 'ISS', 'name': 'Oleg Artemyev'}, {'craft': 'ISS', 'name': 'Denis Matveev'}, {'craft': 'ISS', 'name': 'Sergey Korsakov'}], 'message': 'success'}
#
# El numero de personas que estan en el espacion es de un total de 10
# El astronauta Zhai Zhigang se encuentra en la nave Shenzhou 13
# El astronauta Wang Yaping se encuentra en la nave Shenzhou 13
# El astronauta Ye Guangfu se encuentra en la nave Shenzhou 13
# El astronauta Raja Chari se encuentra en la nave ISS
# El astronauta Tom Marshburn se encuentra en la nave ISS
# El astronauta Kayla Barron se encuentra en la nave ISS
# El astronauta Matthias Maurer se encuentra en la nave ISS
# El astronauta Oleg Artemyev se encuentra en la nave ISS
# El astronauta Denis Matveev se encuentra en la nave ISS
# El astronauta Sergey Korsakov se encuentra en la nave ISS
