# %% [markdown]
# # Ejercicios Modulo 5. Ficheros (Enunciado)
#
# Consideraciones a tener en cuenta:
#
# * Guardar este documento con el siguiente formato para su entrega: __M5_01_nombre_apellido1_apellido2__
# * Realizar los ejercicios con las herramientas vistas en las sesiones.
# * Comentar el código
# * Utilizar nombres de variables apropiados, si vais a guardar una nota, llamar a esa variable nota, no n o x

# %% [markdown]
# **1) En este ejercicio deberás crear un programa que abra y lea un fichero de texto, y nos proporcione la siguiente información:**
#
# * Nombre del fichero
# * Si el fichero esta cerrado o no (True o False)
# * El modo de apertura del fichero
#
# El fichero de texto se denominará **pruebas.txt** y tendrá el siguiente contenido en texto plano (créalo previamente):
#
# ```
# Hola que tal estas
# Esto es una prueba
# Hoy no llueve
# Se acerca la navidad
# Hasta luego y muy buenas
# ```
#
# Busca en la documentación que métodos nos proporcionan la información requerida. Por último, lista el contenido del fichero.
#
# **Aviso importante**: *Si quieres leer un fichero que no se ha escrito directamente con Python, entonces es posible que encuentres errores de codificación al mostrar algunos caracteres. Asegúrate de indicar la codificación del fichero manualmente durante la apertura como argumento en el **open**, por ejemplo con UTF-8:*
#
# ```python
# open(..., encoding="utf8")
# ```

# %%
texto = "Hola que tal estas \nEsto es una prueba \nHoy no llueve \nSe acerca la navidadHasta luego y muy buenas"
fichero = open("pruebas.txt", "w", encoding = "utf-8-sig" )
fichero.write(texto)
fichero.close()
m = True
while (m):
    print("""Seleccione lo que quiere saber sobre su fichero:
    1) Nombre del fichero
    2) La manera de abrirlo
    3) Si el fichero esta cerrado
    4) Cerrar fichero
    5) SALIR""")
    
    # Por si el ususario no mete bien las letras
    try:
        valor = int(input("Introduzca su seleccion: "))
    except ValueError:
        print("Valor introducido INCORRECTO")
        valorCorrecto = True
        while valorCorrecto:
            try:
                valor = int(input("Introduzca de nuevo su seleccion: "))
                valorCorrecto = False
            except ValueError:
                print("ERROR, introduzca un numero del 1 al 5")
                
    # Nombrado del fichero           
    if valor== 1:
        print("El nombre del archivo es: ", fichero.name)

    # El modo de apertura
    elif valor == 2:
        print("""A) Abrirlo y leerlo
B) Abrirlo y sobreescribir algo""")
        seleccion = str(input("Introduzca la manera de abrirlo: "))
        
        if seleccion == "A" or seleccion == "a" :
            lectura = open(fichero.name, "r", encoding = "utf-8-sig")
            textoEscrito = lectura.read()
            lectura.close()
            print(textoEscrito, "\n", "="*40)
        elif seleccion == "B" or seleccion == "b":
            textoNuevo = input("Escriba lo que quiere sobreescribir: ")
            ficheroNuevo = open(fichero.name, "w", encoding = "utf-8-sig")
            ficheroNuevo.write(textoNuevo)
            ficheroNuevo.close()
            print("Fichero SOBRESCRITO")
        else:
            print("Valor introducido NO VALIDO")

    # Saber si el fichero esta cerrado True o abierto False        
    elif valor == 3:
        print("Cerrado =", fichero.closed)

    # Cerrar fichero por si quedara abierto   
    elif valor == 4:
        fichero.close()
        print("Fichero cerrrado")

    # Cerrar programa        
    else:
        fichero.close()  # Por si alguien se olvidase de cerrarlo antes de salir
        m = False

# %% [markdown]
# **2) Sobre el fichero anterior, obtén la siguiente información:**
#
# * Lectura de una línea del fichero
# * Lectura del fichero línea a línea

# %%
texto = "Hola que tal estas \nEsto es una prueba \nHoy no llueve \nSe acerca la navidadHasta luego y muy buenas"
fichero = open("pruebas.txt", "w", encoding = "utf-8-sig" )
fichero.write(texto)
fichero.close()
m = True
while (m):
    print("""Seleccione lo que quiere saber sobre su fichero:
    1) Nombre del fichero
    2) La manera de abrirlo
    3) Si el fichero esta cerrado
    4) Cerrar fichero
    5) Como leer la informacion
    6) SALIR""")
    
    # Por si el ususario no mete bien las letras
    try:
        valor = int(input("Introduzca su seleccion: "))
    except ValueError:
        print("Valor introducido INCORRECTO")
        valorCorrecto = True
        while valorCorrecto:
            try:
                valor = int(input("Introduzca de nuevo su seleccion: "))
                valorCorrecto = False
            except ValueError:
                print("ERROR, introduzca un numero del 1 al 6")
                
    # Nombrado del fichero            
    if valor== 1:
        print("El nombre del archivo es: ", fichero.name)

    # El modo de apertura
    elif valor == 2:
        print("""A) Abrirlo y leerlo
B) Abrirlo y sobreescribir algo""")
        if seleccion == "A" or seleccion == "a" :
            lectura = open(fichero.name, "r", encoding = "utf-8-sig")
            textoEscrito = lectura.read()
            lectura.close()
            print(textoEscrito, "\n", "="*40)
        elif seleccion == "B" or seleccion == "b":
            textoNuevo = input("Escriba lo que quiere sobreescribir: ")
            ficheroNuevo = open(fichero.name, "w", encoding = "utf-8-sig")
            ficheroNuevo.write(textoNuevo)
            ficheroNuevo.close()
            print("Fichero SOBRESCRITO")
        else:
            print(">>>>Valor introducido NO VALIDO<<<<")
            
    # Saber si el fichero esta cerrado True o abierto False
    elif valor == 3:
        print("Cerrado =", fichero.closed)
        
    # Cerrar fichero por si quedara abierto    
    elif valor == 4:
        fichero.close()
        print("Fichero cerrrado")
    
    # Modo de lectura del fichero
    elif valor == 5:
        print("""A) Lectura de una línea del fichero
B) Lectura del fichero línea a línea""")
        seleccionLectura = str(input("Introduzca la manera de abrirlo: "))
        
        if seleccionLectura == "A" or seleccionLectura == "a" :
            lectura = open(fichero.name, "r", encoding = "utf-8-sig")
            textoEscrito = lectura.readline()
            lectura.close()
            print("\n", textoEscrito, "\n", "="*40)
        elif seleccionLectura == "B" or seleccionLectura == "b":
            with open(fichero.name,"r") as fichero:
                for linea in fichero:
                    print(linea)
                fichero.close()
        else:
            print(">>>>Valor introducido NO VALIDO<<<<")

    # Cerrar programa        
    else:
        fichero.close()  # Por si alguien se olvidase de cerrarlo antes de salir
        m = False

# %% [markdown]
# **3) Sobre el fichero anterior, realiza la siguiente operación:**
#
# * Abrir el fichero en modo escritura (concatenando el contenido, sin sobrescribirlo) y escribir una nueva línea de texto
#
# Comprueba que este funcionando correctamente comprobando el fichero (tendrás que cerrarlo y abrirlo para poder visualizar los cambios).

# %%
texto = "Hola que tal estas \nEsto es una prueba \nHoy no llueve \nSe acerca la navidadHasta luego y muy buenas"
fichero = open("pruebas.txt", "w", encoding = "utf-8-sig" )
fichero.write(texto)
fichero.close()

# Añado la informacion al final del texto
fichero = open("pruebas.txt", "a", encoding = "utf-8-sig")
fichero.write("\n Esto que escribo se añade al final")
fichero.close()
fichero = open("pruebas.txt", "r", encoding = "utf-8-sig")
textoAdded = fichero.readlines()
fichero.close()
print(textoAdded[-1])

# %% [markdown]
# **4) Sobre el fichero anterior, realiza la siguiente operación:**
#
# * Abrir el fichero en modo escritura (sobrescribiendo el contenido) y escribir una nueva línea de texto
#
# Comprueba que este funcionando correctamente comprobando el fichero (tendrás que cerrarlo y abrirlo para poder visualizar los cambios).

# %%
texto = "Hola que tal estas \nEsto es una prueba \nHoy no llueve \nSe acerca la navidad \nHasta luego y muy buenas"
fichero = open("pruebas.txt", "w", encoding = "utf-8-sig")
fichero.write(texto)
fichero.close()
fichero = open("pruebas.txt", "r", encoding = "utf-8-sig")
texto = fichero.readlines()
fichero.close()
print(texto)

# Sobreescribo la informacion y muestro por pantalla
fichero = open("pruebas.txt", "w", encoding = "utf-8-sig")
fichero.write("Esto se sobrescribe")
fichero.close()
fichero = open("pruebas.txt", "r", encoding = "utf-8-sig")
textoChanged = fichero.readlines()
fichero.close()
print(textoChanged)

# %% [markdown]
# **5) En este ejercicio deberás crear un programa que lea los datos de un fichero de texto, que transforme cada fila en un diccionario y lo añada a una lista llamada personas. Luego recorre las personas de la lista y para cada una muestra de forma amigable todos sus campos. Por ejemplo así:**
#
# ```
# (id=1) Carlos Pérez => 05/01/1989
# ```
#
# El fichero de texto se denominará **personas.txt** y tendrá el siguiente contenido en texto plano (créalo previamente):
#
# ```
# 1;Carlos;Pérez;05/01/1989
# 2;Manuel;Heredia;26/12/1973
# 3;Rosa;Campos;12/06/1961
# 4;David;García;25/07/2006
# ```
#
# Los campos del diccionario serán por orden: **id**, **nombre**, **apellido** y **nacimiento**.
#
# **Aviso importante**: *Si quieres leer un fichero que no se ha escrito directamente con Python, entonces es posible que encuentres errores de codificación al mostrar algunos caracteres. Asegúrate de indicar la codificación del fichero manualmente durante la apertura como argumento en el **open**, por ejemplo con UTF-8:*
#
# ```python
# open(..., encoding="utf8")
# ```
#
# Pista: Es posible que tengas que recurrir a funciones como replace o split para poder modificar el texto de una línea de texto. Busca documentación sobre ello.

# %%
if __name__ == "__main":
    
    # Programa que lee y crea un lista con datos dentro de un fichero plano, con una determinada estructura de orden
    # Estructura de origen   =>  id;nombre;apellido;nacimiento
    nombreFichero = str(input("Escriba el nombre del fichero (con su extension) que quiera leer: "))
    personas = list()
    try:
        with open(nombreFichero, "r", encoding = "utf8") as fichero:
            for indice, fila in enumerate(fichero):
                listaTexto = fila.split(";")

                # Las variables se crearan de manera dinamica, pudiendo tener infinidad de lineas con esa estructura concreta
                # de id, nombre, apellido y nacimiento.
                globals()["diccionarioFila%s" % indice] = {"id": listaTexto[0], 
                                                           "nombre": listaTexto[1], 
                                                           "apellido": listaTexto[2], 
                                                           "nacimiento": listaTexto[3]}
                personas.append(globals()["diccionarioFila%s" % indice]) # Creamos la lista donde tendremos cada diccionario 
                                                                        # en una determina posicion
            fichero.close()

    except FileNotFoundError:
        print(">>>>El fichero introducido NO SE ENCUENTRA en esta carpeta<<<<")

    for posicion, persona in enumerate(personas):
        personas[posicion]["nacimiento"].replace("\n", "")
        print("(id={}) {} {} => {} ".format(personas[posicion]["id"], 
                                            personas[posicion]["nombre"], 
                                            personas[posicion]["apellido"], 
                                            personas[posicion]["nacimiento"]))
